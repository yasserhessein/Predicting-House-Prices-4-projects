# %% [markdown]
# # 1- Project
# ## Simple Linear Regression

# %% [markdown]
# #### Import Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Importing DataSet

# %%
dataset = pd.read_csv("pr_house_data.csv")
space=dataset['sqft_living']# Area of homes
price=dataset['price']

x = np.array(space).reshape(-1, 1)
y = np.array(price)

# %% [markdown]
# #### Splitting the data into Train and Test

# %%
from sklearn.model_selection import train_test_split 
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=1/3, random_state=0)

# %% [markdown]
# #### Fitting simple linear regression to the Training Set

# %%
from sklearn.linear_model import LinearRegression 
regressor = LinearRegression()
regressor.fit(xtrain, ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# #### Predicting the prices

# %%
pred = regressor.predict(xtest)

# %% [markdown]
# #### Visualizing the training Test Results

# %%
plt.scatter(xtrain, ytrain, color= 'black')
plt.plot(xtrain, regressor.predict(xtrain), color = 'green')
plt.title ("Visuals for Training Dataset")
plt.xlabel("Space")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# #### Visualizing the Test Results

# %%
plt.scatter(xtest, ytest, color= 'black')
plt.plot(xtrain, regressor.predict(xtrain), color = 'green')
plt.title("Visuals for Test DataSet")
plt.xlabel("Space")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# #### If we have a new house just need the area

# %%
print (regressor.predict([[1200]]))
# Out:
# [299522.49076802]

# %%
print (regressor.predict([[45808]]))
# Out:
# [12513273.984472]

# %%
print (regressor.predict([[31011]]))
# Out:
# [8461828.48473344]

# %% [markdown]
# # Good luck
# ## Yasir Hussein Shakir
# ## E : Yasserhesseinshakir@yahoo.com
# ## T : +9647905767055
